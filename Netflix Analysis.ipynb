# %% [markdown]
# <div style="background:linear-gradient(to right, #4facfe, #00f2fe);
# padding:15px;
# border-radius:10px;
# color:white;">
#
# <h1>📊 Netflix Data Analysis Portfolio Project</h1>
#
# <h3>🟢 Excel
# 🔵 SQL
# 🟣 Power BI
# 🟠 Python
# 🐼 Pandas
# 🔢 NumPy
# 📊 Matplotlib</h3>
#
# </div>

# %% [markdown]
# ## 🎯 Import Data From `CSV` to `Pandas`

# %%
import pandas as pd

df = pd.read_csv(
    r"C:\Users\ayush\OneDrive\Desktop\ExcelData\Netflix Proj\Netflix Userbase.csv"
)

df.head()
# Out:
#    User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0        1             Basic               10  15-01-22          10-06-23
# 1        2           Premium               15  05-09-21          22-06-23
# 2        3          Standard               12  28-02-23          27-06-23
# 3        4          Standard               12  10-07-22          26-06-23
# 4        5             Basic               10  01-05-23          28-06-23
#
#           Country  Age  Gender      Device Plan Duration
# 0   United States   28    Male  Smartphone       1 Month
# 1          Canada   35  Female      Tablet       1 Month
# 2  United Kingdom   42    Male    Smart TV       1 Month
# 3       Australia   51  Female      Laptop       1 Month
# 4         Germany   33    Male  Smartphone       1 Month

# %% [markdown]
# ## 🎯 Check `Data Type`

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   User ID            2500 non-null   int64
#  1   Subscription Type  2500 non-null   object
#  2   Monthly Revenue    2500 non-null   int64
#  3   Join Date          2500 non-null   object
#  4   Last Payment Date  2500 non-null   object
#  5   Country            2500 non-null   object
#  6   Age                2500 non-null   int64
#  7   Gender             2500 non-null   object
#  8   Device             2500 non-null   object
#  9   Plan Duration      2500 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 195.4+ KB

# %% [markdown]
# ## 🎯 Convert Date DataType `Obj` to `datetime64[ns]`

# %%
df["Join Date"] = pd.to_datetime(df["Join Date"], format = "mixed")

df.head()
# Out:
#    User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 0        1             Basic               10 2022-01-15          10-06-23
# 1        2           Premium               15 2021-05-09          22-06-23
# 2        3          Standard               12 2023-02-28          27-06-23
# 3        4          Standard               12 2022-10-07          26-06-23
# 4        5             Basic               10 2023-01-05          28-06-23
#
#           Country  Age  Gender      Device Plan Duration
# 0   United States   28    Male  Smartphone       1 Month
# 1          Canada   35  Female      Tablet       1 Month
# 2  United Kingdom   42    Male    Smart TV       1 Month
# 3       Australia   51  Female      Laptop       1 Month
# 4         Germany   33    Male  Smartphone       1 Month

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   User ID            2500 non-null   int64
#  1   Subscription Type  2500 non-null   object
#  2   Monthly Revenue    2500 non-null   int64
#  3   Join Date          2500 non-null   datetime64[ns]
#  4   Last Payment Date  2500 non-null   object
#  5   Country            2500 non-null   object
#  6   Age                2500 non-null   int64
#  7   Gender             2500 non-null   object
#  8   Device             2500 non-null   object
#  9   Plan Duration      2500 non-null   object
# dtypes: datetime64[ns](1), int64(3), object(6)
# memory usage: 195.4+ KB

# %%
df["Last Payment Date"] = pd.to_datetime(df["Last Payment Date"], format = "mixed")
df.head()
# Out:
#    User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 0        1             Basic               10 2022-01-15        2023-10-06
# 1        2           Premium               15 2021-05-09        2023-06-22
# 2        3          Standard               12 2023-02-28        2023-06-27
# 3        4          Standard               12 2022-10-07        2023-06-26
# 4        5             Basic               10 2023-01-05        2023-06-28
#
#           Country  Age  Gender      Device Plan Duration
# 0   United States   28    Male  Smartphone       1 Month
# 1          Canada   35  Female      Tablet       1 Month
# 2  United Kingdom   42    Male    Smart TV       1 Month
# 3       Australia   51  Female      Laptop       1 Month
# 4         Germany   33    Male  Smartphone       1 Month

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   User ID            2500 non-null   int64
#  1   Subscription Type  2500 non-null   object
#  2   Monthly Revenue    2500 non-null   int64
#  3   Join Date          2500 non-null   datetime64[ns]
#  4   Last Payment Date  2500 non-null   datetime64[ns]
#  5   Country            2500 non-null   object
#  6   Age                2500 non-null   int64
#  7   Gender             2500 non-null   object
#  8   Device             2500 non-null   object
#  9   Plan Duration      2500 non-null   object
# dtypes: datetime64[ns](2), int64(3), object(5)
# memory usage: 195.4+ KB

# %% [markdown]
# ## 🎯 Check `NULL` values in the DataSet

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## 🎯 Check `Duplicate` rows in the DataSet

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## 🎯 Check `Duplicate` columns in the DataSet

# %%
df.columns.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## 🎯 Check `Row Size` in the DataSet

# %%
df.size
# Out:
# 25000

# %% [markdown]
# ## 🎯 Check `Column Size` in the DataSet

# %%
df.columns.size
# Out:
# 10

# %% [markdown]
# ## 🎯 Check `Column Name` in the DataSet

# %%
df.columns
# Out:
# Index(['User ID', 'Subscription Type', 'Monthly Revenue', 'Join Date',
#        'Last Payment Date', 'Country', 'Age', 'Gender', 'Device',
#        'Plan Duration'],
#       dtype='object')

# %% [markdown]
# ## 🎯 Check columns contain `numeric data`

# %%
df.select_dtypes(include='number').columns
# Out:
# Index(['User ID', 'Monthly Revenue', 'Age'], dtype='object')

# %% [markdown]
# ## 🎯 Check columns contain `Text data`

# %%
df.select_dtypes(include= 'object').columns
# Out:
# Index(['Subscription Type', 'Country', 'Gender', 'Device', 'Plan Duration'], dtype='object')

# %% [markdown]
# ## 🎯 Pick `Random Rows`

# %%
df.sample(5)
# Out:
#       User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 892       893          Standard               13 2022-07-30        2023-01-07
# 1808     1809          Standard               15 2022-09-17        2023-06-07
# 696       697             Basic               12 2022-06-10        2023-06-29
# 418       419          Standard               11 2022-10-30        2023-06-27
# 192       193          Standard               11 2022-05-08        2023-06-25
#
#              Country  Age  Gender    Device Plan Duration
# 892    United States   42  Female  Smart TV       1 Month
# 1808          Canada   40  Female    Tablet       1 Month
# 696            Spain   43    Male  Smart TV       1 Month
# 418            Spain   27  Female    Laptop       1 Month
# 192   United Kingdom   50    Male    Laptop       1 Month

# %% [markdown]
# ## 🎯 Check DataSet `shape`

# %%
df.shape
# Out:
# (2500, 10)
